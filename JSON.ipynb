# %%
import json

# %%
data = {"name":"Abhishek", "age":25}
json_data  = json.dumps(data)
print(json_data)
type(json_data)
# Out:
# {"name": "Abhishek", "age": 25}
# str

# %%
json_dt = '{"name":"anu" , "age": 25}'
print(json_dt)
print(type(json_dt))

data  = json.loads(json_dt)
print(data)
print(type(data))
# Out:
# {"name":"anu" , "age": 25}
# <class 'str'>
# {'name': 'anu', 'age': 25}
# <class 'dict'>

# %%
data_tt  = {"name":"abhishek","last _name":"mishra"}
data_tt = json.dumps(data_tt)
print(data_tt)
# Out:
# {"name": "abhishek", "last _name": "mishra"}
